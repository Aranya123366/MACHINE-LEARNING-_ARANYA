# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y=make_regression(n_samples=100,n_features=1,n_targets=1,n_informative=1,noise=20)

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [35.23859577]
# 0.014395099807013367

# %%
class GDregressor:
  def __init__(self,learning_rate,epoches):
    self.m=0
    self.b=1
    self.lr=learning_rate
    self.epoches=epoches
  def fit(self,x,y):
    #calculate b using gradient descent
    for i in range(self.epoches):
      loss_slope_b=-2*np.sum(y-self.m*x.ravel()-self.b)
      loss_slope_m=-2*np.sum((y-self.m*x.ravel()-self.b)*x.ravel())
      self.b=self.b-self.lr*loss_slope_b
      self.m=self.m-self.lr*loss_slope_m
    print(self.b,self.m)
  def predict(self,x):
    return self.m*x+self.b

# %%
gd=GDregressor(0.001,100)
gd.fit(x,y)
# Out:
# 0.01439510415492124 35.23859575819649

# %%
gd.predict(5)
# Out:
# np.float64(176.20737389513735)
